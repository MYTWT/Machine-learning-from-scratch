# %%
import pandas as pd
from sklearn.model_selection import train_test_split
# from data_profiling import ProfileReport
df = pd.read_csv('../datasets/diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 0              6      148  ...   50        1
# 1              1       85  ...   31        0
# 2              8      183  ...   32        1
# 3              1       89  ...   21        0
# 4              0      137  ...   33        1
# ..           ...      ...  ...  ...      ...
# 763           10      101  ...   63        0
# 764            2      122  ...   27        0
# 765            5      121  ...   30        0
# 766            1      126  ...   47        1
# 767            1       93  ...   23        0
#
# [768 rows x 9 columns]

# %%
# profile = ProfileReport(df,title = 'Diabetes reports')

# %%
# profile.to_file('Diabetes.html')

# %% [markdown]
# ## 1.Tach du lieu

# %%
target = 'Outcome'
x = df.drop(columns=target)
y = df[target]
print(x)
y
# Out:
#      Pregnancies  Glucose  BloodPressure  ...   BMI  DiabetesPedigreeFunction  Age
# 0              6      148             72  ...  33.6                     0.627   50
# 1              1       85             66  ...  26.6                     0.351   31
# 2              8      183             64  ...  23.3                     0.672   32
# 3              1       89             66  ...  28.1                     0.167   21
# 4              0      137             40  ...  43.1                     2.288   33
# ..           ...      ...            ...  ...   ...                       ...  ...
# 763           10      101             76  ...  32.9                     0.171   63
# 764            2      122             70  ...  36.8                     0.340   27
# 765            5      121             72  ...  26.2                     0.245   30
# 766            1      126             60  ...  30.1                     0.349   47
# 767            1       93             70  ...  30.4                     0.315   23
#
# [768 rows x 8 columns]
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x,y, 
    test_size= 0.2,
    random_state= 1009)

# %% [markdown]
# ## 2 Tien xu ly du lieu

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train =scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# ## 3. Chon mo hinh

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_predict = model.predict(x_test)
for i, j in zip(y_predict, y_test):
    print("Prediction_value : {} and Actual_value : {}".format(i,j))
# Out:
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 1
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 1
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 1
# Prediction_value : 1 and Actual_value : 1
# Prediction_value : 1 and Actual_value : 1
# Prediction_value : 0 and Actual_value : 1
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 1 and Actual_value : 1
# Prediction_value : 1 and Actual_value : 1
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 1 and Actual_value : 1
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 1 and Actual_value : 1
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 1 and Actual_value : 1
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 1 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 1
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 1
# Prediction_value : 1 and Actual_value : 1
# Prediction_value : 0 and Actual_value : 1
# Prediction_value : 1 and Actual_value : 1
# Prediction_value : 1 and Actual_value : 1
# Prediction_value : 1 and Actual_value : 1
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 1 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 1
# Prediction_value : 1 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 1 and Actual_value : 1
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 1
# Prediction_value : 0 and Actual_value : 1
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 1 and Actual_value : 1
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 1
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 1 and Actual_value : 1
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 1 and Actual_value : 0
# Prediction_value : 1 and Actual_value : 1
# Prediction_value : 1 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 1 and Actual_value : 1
# Prediction_value : 0 and Actual_value : 1
# Prediction_value : 0 and Actual_value : 1
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 1 and Actual_value : 1
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 1 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 1 and Actual_value : 0
# Prediction_value : 1 and Actual_value : 1
# Prediction_value : 0 and Actual_value : 1
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 1
# Prediction_value : 1 and Actual_value : 1
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 1
# Prediction_value : 1 and Actual_value : 1
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 1 and Actual_value : 1
# Prediction_value : 1 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 1 and Actual_value : 1
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 1
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 1 and Actual_value : 1
# Prediction_value : 1 and Actual_value : 1
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 1 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 1
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 1 and Actual_value : 0
# Prediction_value : 1 and Actual_value : 1
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 1
# Prediction_value : 1 and Actual_value : 1
# Prediction_value : 0 and Actual_value : 1
# Prediction_value : 1 and Actual_value : 0
# Prediction_value : 1 and Actual_value : 1
# Prediction_value : 1 and Actual_value : 1
# Prediction_value : 1 and Actual_value : 1
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 1
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 1
# Prediction_value : 1 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 1 and Actual_value : 1
# Prediction_value : 1 and Actual_value : 1
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 1
# Prediction_value : 0 and Actual_value : 0
# Prediction_value : 0 and Actual_value : 0

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
print("Accuracy score: {}".format(accuracy_score(y_test,y_predict)))
print("Precision score : {}".format(precision_score(y_test,y_predict)))
print("Recall score : {}".format(recall_score(y_test,y_predict)))
print("F1 score : {}".format(f1_score(y_test,y_predict)))
# Out:
# Accuracy score: 0.7727272727272727
# Precision score : 0.7209302325581395
# Recall score : 0.5740740740740741
# F1 score : 0.6391752577319587

# %% [markdown]
# ## 4/ Toi uu mo hinh tot nhat

# %%
from lazypredict.Supervised import LazyClassifier
# Initialize LazyClassifier
clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)

# Fit and evaluate models
models, predictions = clf.fit(x_train, x_test, y_train, y_test)

# Display results
print(models)
# Out:
#                                Accuracy  ...  Time Taken
# Model                                    ...
# CalibratedClassifierCV         0.779221  ...    0.035323
# LinearSVC                      0.779221  ...    0.013892
# SVC                            0.779221  ...    0.025720
# LogisticRegression             0.779221  ...    0.015410
# GaussianNB                     0.766234  ...    0.014964
# KNeighborsClassifier           0.759740  ...    0.017087
# NearestCentroid                0.746753  ...    0.014967
# LinearDiscriminantAnalysis     0.772727  ...    0.013464
# RidgeClassifier                0.772727  ...    0.013421
# RidgeClassifierCV              0.772727  ...    0.014247
# NuSVC                          0.772727  ...    0.026374
# ExtraTreesClassifier           0.759740  ...    0.109113
# BaggingClassifier              0.746753  ...    0.034195
# RandomForestClassifier         0.759740  ...    0.133169
# LabelPropagation               0.727273  ...    0.021645
# LabelSpreading                 0.727273  ...    0.022926
# QuadraticDiscriminantAnalysis  0.740260  ...    0.015013
# AdaBoostClassifier             0.733766  ...    0.084876
# DecisionTreeClassifier         0.720779  ...    0.014951
# SGDClassifier                  0.740260  ...    0.015491
# Perceptron                     0.649351  ...    0.014730
# BernoulliNB                    0.707792  ...    0.014338
# ExtraTreeClassifier            0.668831  ...    0.015091
# PassiveAggressiveClassifier    0.558442  ...    0.013903
# DummyClassifier                0.649351  ...    0.013190
#
# [25 rows x 7 columns]
